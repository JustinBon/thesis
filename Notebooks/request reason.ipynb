# %%
import pandas as pd

import os
import re
import json

# %%
df = pd.read_csv('..\\data\\ocred\\files_df.csv', index_col = 0)

# %% [markdown]
# ## Reason for request

# %%
test = df[(df.full_name.str.contains('_besluit') & (df.page == 1))]

for t in test.full_name:
    text = df[df.full_name == t].text.values[0]
    text = re.split('\n{2,}', text)
    text = [x for x in text if x != '']
    print(t)
    for i in range(len(text)):
        if '(hierna: Wob' in text[i]:
            textPart = text[i]
            break
    print(textPart)
    textPart = textPart.replace('\n', ' ')
    print(re.findall('verzocht([^.]+?)\.', textPart), '\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\justin\OneDrive - UvA\Studie\Data Science\Thesis\Knowledge extraction\Notebooks\request reason.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/justin/OneDrive%20-%20UvA/Studie/Data%20Science/Thesis/Knowledge%20extraction/Notebooks/request%20reason.ipynb#ch0000004?line=4'>5</a> text = re.split('\n{2,}', text)
#       <a href='vscode-notebook-cell:/c%3A/Users/justin/OneDrive%20-%20UvA/Studie/Data%20Science/Thesis/Knowledge%20extraction/Notebooks/request%20reason.ipynb#ch0000004?line=5'>6</a> text = [x for x in text if x != '']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/justin/OneDrive%20-%20UvA/Studie/Data%20Science/Thesis/Knowledge%20extraction/Notebooks/request%20reason.ipynb#ch0000004?line=6'>7</a> text = text.replace('\n', ' ')
# ...

# %%
test = df[(df.full_name.str.contains('_besluit') & (df.page == 1))]

for t in test.full_name:
    text = df[df.full_name == t].text.values[0]
    text = text.replace('\n', ' ')
    print(re.findall('verzocht([^.]+?)\.', text), '\n')
# Out:
# [' om een overzicht van de agenda-afspraken van de minister, alsmede beide staatssecretarissen en alle leden van de bestuursraad van het ministerie van Financiën']
#
# [' om openbaarmaking van de documenten over de door het Openbaar Ministerie (hierna: OM) genomen besluiten om minister Grapperhaus te vervolgen voor overtreding van de coronaregels']
#
# [' inzake de totstandkoming van het COVID beleid binnen DJI']
#
# [' om informatie over de Baangerelateerde Investeringskorting (BIK)']
#
# []
#
# [' om documenten inzake het recht op terugbetaling bij een geannuleerde vlucht met als alternatief een voucher']
#
# [' over de repatriëring van Nederlanders uit Marokko in verband met de coronapandemie']
#
# [' wordt om openbaarmaking van documenten inzake Covid-19', ' deze informatie openbaar te maken']
#
# [' wordt om openbáarmaking van documenten inzake Covid-19', ' deze informatie openbaar te maken']
#
# ...

# %%
test = 'In uw e-mail van 20 september 2020 heeft u met een beroep op de Wet openbaarheid van bestuur (hierna: Wob) verzocht om informatie over de Baangerelateerde Investeringskorting (BIK).'

re.findall('verzocht([^.]+?)\.', test)
# Out:
# [' om informatie over de Baangerelateerde Investeringskorting (BIK)']

# %%
text = df[df.full_name == '8b8890d6058f24465456cc410f4262ae_besluit-1.txt'].text.values[0]
print(text)
# Out:
# Ministerie van Financiën
#
#
#
# > Retouradres Postbus 20201 2500 EE Den Haag
#
# Directie Juridische Zaken
#
# Korte Voorhout 7
# 2511 CW Den Haag
# Postbus 20201
#
# 2500 EE Den Haag
# www.rijksoverheid.nl
#
# Ons kenmerk
# 2021-0000020482
# Bijlagen
# A - Relevante gronden Wob
# B - Inventarislijst
# C - Openbaar te maken
#
# Datum 11 juni 2021 documenten
#
# Betreft Besluit inzake uw Wob-verzoek over de
#
# Baangerelateerde Investeringskorting (BIK)
#
# Geachte
#
# In uw brief van 18 september 2020, ontvangen op 21 september 2020, heeft u
# met een beroep op de Wet openbaarheid van bestuur (hierna: Wob)
#
# verzocht om informatie over de Baangerelateerde Investeringskorting (BIK) en
# wijziging van de Vennootschapsbelasting (VPB). U vraagt om alle documenten
# over de invoering van de BIK zoals genoemd in de Miljoenennota 2021 en alle
# documenten over de wijziging van de VPB zoals in de Miljoenennota 2021 en het
# Belastingplan 2021 zijn opgenomen.
#
# ...
